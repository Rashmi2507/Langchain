# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_community.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

## Langsmith tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
## Prompt Template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant. Please respond to the question asked"),
        ("user","Question:{question}")
    ]
)

# %%
## Ollama llama2 model
llm = Ollama(model="llama2")
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

# %%
question = chain.invoke({"question":"what is genrative AI?"})

# %%
question
# Out:
# "Assistant: Hello! I'm glad you're interested in learning about generative AI! Generative AI refers to a type of artificial intelligence that can generate new and original content, such as images, videos, music, or text. This is in contrast to other types of AI that focus on recognizing patterns or making predictions based on existing data.\n\nGenerative AI models use complex algorithms to learn the patterns and structures within the data they are trained on, and then use this knowledge to create new content that resembles the original data. For example, a generative AI model trained on images of dogs could generate new images of dogs that look like they were taken by a photographer.\n\nThere are several different approaches to generative AI, including:\n\n1. Generative Adversarial Networks (GANs): This approach involves training two neural networks to work together to generate new content. One network generates samples, while the other network tries to distinguish the generated samples from real samples. The two networks are trained together, and over time, the generator network learns to produce more realistic samples that can fool the discriminator network.\n2. Variational Autoencoders (VAEs): This approach involves training a neural network to learn a probabilistic representation of the data it is trained on. The network learns to encode the data into a latent space, which can be used to generate new content by sampling from the latent space and passing the sample through a decoder network.\n3. Generative Transformer Networks (GTNs): This approach involves training a neural network to learn the patterns and structures within the data it is trained on, and then using this knowledge to generate new content. GTNs use a transformer architecture, which is particularly well-suited for generating long sequences of data, such as text or time-series data.\n4. Evolutionary Algorithms: This approach involves using evolutionary algorithms, such as genetic algorithms or evolution strategies, to evolve new content over time. The algorithms work by iteratively mutating and selecting the most promising content, until an optimal solution is reached.\n\nGenerative AI has many potential applications, including:\n\n1. Art and Design: Generative AI could be used to create new forms of art and design that are innovative and creative.\n2. Music: Generative AI could be used to compose new music or to help musicians generate new ideas for their compositions.\n3. Writing: Generative AI could be used to write new stories, poetry, or other types of writing.\n4. Data Augmentation: Generative AI could be used to augment existing data sets with new, synthesized data that can help improve the performance of machine learning models.\n5. Drug Discovery: Generative AI could be used to generate new molecular structures that could be potential drugs.\n6. Robotics and Control Systems: Generative AI could be used to generate new control policies for robots or other complex systems.\n7. Virtual Reality and Gaming: Generative AI could be used to create immersive virtual environments or to generate new levels, characters, or other elements in video games.\n\nI hope this helps you understand generative AI! Let me know if you have any further questions."
