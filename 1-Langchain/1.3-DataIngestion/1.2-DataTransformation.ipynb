# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("sample.pdf")
docs = loader.load()
docs
# Out:
# C:\Users\rashm\AppData\Local\Temp\ipykernel_11948\3257423302.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# [Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="LANGCHAIN: Building Intelligent Applications with Language Models \n \nHello everyone, and welcome! Today, I want to introduce you to Langchain, \na revolutionary framework that is transforming how we build applications \nwith Large Language Models. \n \n## What is Langchain? \n \nLangchain is an open-source framework designed to simplify the \ndevelopment of applications powered by language models. It provides a set \nof tools, abstractions, and integrations that make it easier to work with \nLLMs like GPT-4, Llama, and others. Think of it as a bridge between your \napplication and the power of language models. \n \n## The Core Problem \n \nBefore Langchain, building LLM applications was complex. Developers had \nto manage API calls, handle tokens, maintain conversation history, manage \ndata pipelines, and integrate multiple components. This was time-\nconsuming and error-prone. Langchain solves this by providing ready-to-\nuse components and abstractions. \n \n## Key Components of Langchain \n \nFirst, let's talk about Models. Langchain supports multiple LLM \nproviders. Whether you're using OpenAI's GPT series, Open source models \nlike Ollama, or other providers, Langchain provides a unified interface. \nThis means you can switch between models without changing your code \nsignificantly. \n \nSecond, we have Prompts and Templates. Langchain helps you structure \nprompts effectively. You can create reusable prompt templates with \nvariables, making it easy to format inputs for your language models. This \nis crucial because the quality of your prompts directly impacts the \nquality of your outputs. \n \nThird, Chains are a fundamental concept. A chain is a sequence of calls \nto components - typically LLMs, but also other tools. Instead of making \nindividual API calls, you can create chains that automate complex \nworkflows. For example, you might create a chain that reads data, \nprocesses it, generates an answer, and formats the output. \n \nFourth, Memory is essential for conversational AI. Langchain provides \nseveral memory types to maintain conversation history. You can keep track \nof previous interactions, which is vital for creating chatbots that \nunderstand context and can have meaningful, coherent conversations. \n \nFifth, Agents are intelligent systems that can make decisions. Unlike \nchains with fixed sequences, agents use an LLM to decide which tools to \nuse and in what order. They can reason through problems, use external \ntools when needed, and adapt their approach based on circumstances. This \nis like giving your application a brain that can think and decide. \n \nSixth, Data Ingestion and Vectorization. Langchain helps you load data \nfrom various sources - PDFs, websites, databases, APIs. It can split \ndocuments into manageable chunks and convert them into vector embeddings. \nThis is crucial for building applications that work with large knowledge \nbases."),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="Finally, we have Retrievers and Indexes. These components help you find \nrelevant information from your data. When building a question-answering \nsystem, for instance, you can retrieve the most relevant chunks from your \nknowledge base and pass them to the LLM for answering. \n \n## Real-World Applications \n \nSo what can you build with Langchain? \n \nQuestion-Answering Systems: Upload documents, ask questions, and get \nanswers based on your specific data. Unlike just using ChatGPT, your \nsystem can be grounded in your own knowledge base. \n \nChatbots: Build conversational agents that understand context, remember \nprevious interactions, and can perform actions by using tools and APIs. \n \nSummarization Tools: Automatically summarize long documents or web pages, \nmaintaining key information while reducing length. \n \nData Analysis Assistants: Create agents that can analyze data, generate \ninsights, and write reports automatically. \n \nContent Generation Pipelines: Build workflows that generate content, from \nblog posts to code, with multiple steps and quality checks. \n \n## Langchain's Flexibility \n \nOne of Langchain's greatest strengths is its flexibility. Whether you \nwant to use OpenAI's powerful GPT models, run open-source models locally \nwith Ollama, or use other providers, Langchain supports them all. This \ndemocratizes AI development - you're not locked into any single provider. \n \n## Integrations \n \nLangchain integrates with countless external services. Vector databases \nlike Pinecone and Weaviate for storing embeddings. Tools like Google \nSearch, Calculator, and APIs. Document loaders for PDFs, CSVs, and more. \nThis ecosystem means you can build complex, powerful applications without \nreinventing the wheel. \n \n## Why Learn Langchain? \n \nThe demand for LLM applications is skyrocketing. Companies across \nindustries are looking to integrate AI into their products and services. \nLearning Langchain puts you at the forefront of this revolution. You'll \nbe able to build applications that seemed impossible just a few years \nago. \n \nIt abstracts away complexity, allowing you to focus on solving business \nproblems rather than wrestling with API details. It's relatively easy to \nlearn if you have Python knowledge, yet powerful enough to build \nproduction-grade applications. \n \n## Getting Started \n \nStarting with Langchain is straightforward. Install it via pip, set up \nyour API keys for the language models you want to use, and start"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content="building. The documentation is comprehensive, and the community is active \nand supportive. \n \nBegin with simple applications - a basic chatbot, a Q&A system over your \ndocuments. Understand the core concepts: models, prompts, chains, and \nmemory. Then explore more advanced features like agents and integrations. \n \n## The Future \n \nLangchain is rapidly evolving. New features are being added constantly. \nThe framework is becoming the de facto standard for building LLM \napplications. Whether you're a startup building the next AI unicorn or an \nenterprise integrating AI into existing systems, Langchain is an \ninvaluable tool. \n \n## Conclusion \n \nLangchain democratizes AI development. It transforms the complex \nlandscape of building with language models into something accessible and \npractical. The framework handles the heavy lifting while you focus on \ncreating value. \n \nAs we move into an era where AI is becoming ubiquitous, skills like \nLangchain will be increasingly valuable. Start learning today. Experiment \nwith building applications. Share your creations. The possibilities are \ntruly limitless. \n \nThe future of software development is intertwined with language models, \nand Langchain is the tool that makes building that future possible. \n \nThank you for your attention. I hope this speech has given you a solid \nunderstanding of what Langchain is and why it's worth learning. Now go \nbuild something amazing!")]

# %% [markdown]
# ### How to recursively split text by characters

# %%
# %pip install langchain-text-splitters -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=5)
split_docs = text_splitter.split_documents(docs)
split_docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='LANGCHAIN: Building Intelligent Applications with'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='with Language Models'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Hello everyone, and welcome! Today, I want to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='to introduce you to Langchain,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='a revolutionary framework that is transforming'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='how we build applications'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='with Large Language Models.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='## What is Langchain?'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Langchain is an open-source framework designed to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='to simplify the'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='development of applications powered by language'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='models. It provides a set'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='of tools, abstractions, and integrations that'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='that make it easier to work with'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='LLMs like GPT-4, Llama, and others. Think of it'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='it as a bridge between your'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='application and the power of language models.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='## The Core Problem'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Before Langchain, building LLM applications was'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='was complex. Developers had'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='to manage API calls, handle tokens, maintain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='conversation history, manage'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='data pipelines, and integrate multiple'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='components. This was time-'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='consuming and error-prone. Langchain solves this'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='this by providing ready-to-'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='use components and abstractions.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='## Key Components of Langchain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="First, let's talk about Models. Langchain"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='supports multiple LLM'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="providers. Whether you're using OpenAI's GPT"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='GPT series, Open source models'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='like Ollama, or other providers, Langchain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='provides a unified interface.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='This means you can switch between models without'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='changing your code'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='significantly.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Second, we have Prompts and Templates. Langchain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='helps you structure'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='prompts effectively. You can create reusable'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='prompt templates with'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='variables, making it easy to format inputs for'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='for your language models. This'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='is crucial because the quality of your prompts'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='directly impacts the'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='quality of your outputs.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Third, Chains are a fundamental concept. A chain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='is a sequence of calls'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='to components - typically LLMs, but also other'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='tools. Instead of making'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='individual API calls, you can create chains that'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='that automate complex'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='workflows. For example, you might create a chain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='that reads data,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='processes it, generates an answer, and formats'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='the output.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Fourth, Memory is essential for conversational'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='AI. Langchain provides'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='several memory types to maintain conversation'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='history. You can keep track'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='of previous interactions, which is vital for'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='for creating chatbots that'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='understand context and can have meaningful,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='coherent conversations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Fifth, Agents are intelligent systems that can'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='can make decisions. Unlike'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='chains with fixed sequences, agents use an LLM to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='to decide which tools to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='use and in what order. They can reason through'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='problems, use external'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='tools when needed, and adapt their approach based'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='on circumstances. This'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='is like giving your application a brain that can'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='can think and decide.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Sixth, Data Ingestion and Vectorization.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Langchain helps you load data'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='from various sources - PDFs, websites, databases,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='APIs. It can split'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='documents into manageable chunks and convert them'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='them into vector embeddings.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='This is crucial for building applications that'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='that work with large knowledge'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='bases.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Finally, we have Retrievers and Indexes. These'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='components help you find'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='relevant information from your data. When'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='When building a question-answering'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='system, for instance, you can retrieve the most'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='most relevant chunks from your'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='knowledge base and pass them to the LLM for'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='for answering.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='## Real-World Applications'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='So what can you build with Langchain?'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Question-Answering Systems: Upload documents, ask'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='ask questions, and get'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='answers based on your specific data. Unlike just'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='just using ChatGPT, your'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='system can be grounded in your own knowledge'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='base.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Chatbots: Build conversational agents that'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='that understand context, remember'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='previous interactions, and can perform actions by'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='by using tools and APIs.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Summarization Tools: Automatically summarize long'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='long documents or web pages,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='maintaining key information while reducing'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='length.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Data Analysis Assistants: Create agents that can'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='can analyze data, generate'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='insights, and write reports automatically.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Content Generation Pipelines: Build workflows'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='that generate content, from'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='blog posts to code, with multiple steps and'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='and quality checks.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="## Langchain's Flexibility"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="One of Langchain's greatest strengths is its"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='its flexibility. Whether you'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="want to use OpenAI's powerful GPT models, run"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='run open-source models locally'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='with Ollama, or use other providers, Langchain'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='supports them all. This'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="democratizes AI development - you're not locked"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='into any single provider.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='## Integrations'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Langchain integrates with countless external'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='services. Vector databases'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='like Pinecone and Weaviate for storing'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='embeddings. Tools like Google'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Search, Calculator, and APIs. Document loaders'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='for PDFs, CSVs, and more.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='This ecosystem means you can build complex,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='powerful applications without'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='reinventing the wheel.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='## Why Learn Langchain?'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='The demand for LLM applications is skyrocketing.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Companies across'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='industries are looking to integrate AI into their'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='products and services.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Learning Langchain puts you at the forefront of'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content="of this revolution. You'll"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='be able to build applications that seemed'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='impossible just a few years'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='ago.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='It abstracts away complexity, allowing you to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='to focus on solving business'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='problems rather than wrestling with API details.'),
# ...
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='enough to build'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='production-grade applications.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='## Getting Started'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Starting with Langchain is straightforward.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Install it via pip, set up'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='your API keys for the language models you want to'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='to use, and start'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='building. The documentation is comprehensive, and'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='and the community is active'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='and supportive.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Begin with simple applications - a basic chatbot,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='a Q&A system over your'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='documents. Understand the core concepts: models,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='prompts, chains, and'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='memory. Then explore more advanced features like'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='like agents and integrations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='## The Future'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Langchain is rapidly evolving. New features are'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='are being added constantly.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='The framework is becoming the de facto standard'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='for building LLM'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content="applications. Whether you're a startup building"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='the next AI unicorn or an'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='enterprise integrating AI into existing systems,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Langchain is an'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='invaluable tool. \n \n## Conclusion'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Langchain democratizes AI development. It'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='It transforms the complex'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='landscape of building with language models into'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='into something accessible and'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='practical. The framework handles the heavy'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='lifting while you focus on'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='creating value.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='As we move into an era where AI is becoming'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='ubiquitous, skills like'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Langchain will be increasingly valuable. Start'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='learning today. Experiment'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='with building applications. Share your creations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='The possibilities are'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='truly limitless.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='The future of software development is intertwined'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='with language models,'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='and Langchain is the tool that makes building'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='that future possible.'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Thank you for your attention. I hope this speech'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='has given you a solid'),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content="understanding of what Langchain is and why it's"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content="it's worth learning. Now go"),
#  Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='build something amazing!')]

# %%
split_docs[0]
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='LANGCHAIN: Building Intelligent Applications with')

# %%
split_docs[1]
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='with Language Models')

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("speech.txt")
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="LANGCHAIN: Building Intelligent Applications with Language Models\n\nHello everyone, and welcome! Today, I want to introduce you to Langchain, a revolutionary framework that is transforming how we build applications with Large Language Models.\n\n## What is Langchain?\n\nLangchain is an open-source framework designed to simplify the development of applications powered by language models. It provides a set of tools, abstractions, and integrations that make it easier to work with LLMs like GPT-4, Llama, and others. Think of it as a bridge between your application and the power of language models.\n\n## The Core Problem\n\nBefore Langchain, building LLM applications was complex. Developers had to manage API calls, handle tokens, maintain conversation history, manage data pipelines, and integrate multiple components. This was time-consuming and error-prone. Langchain solves this by providing ready-to-use components and abstractions.\n\n## Key Components of Langchain\n\nFirst, let's talk about Models. Langchain supports multiple LLM providers. Whether you're using OpenAI's GPT series, Open source models like Ollama, or other providers, Langchain provides a unified interface. This means you can switch between models without changing your code significantly.\n\nSecond, we have Prompts and Templates. Langchain helps you structure prompts effectively. You can create reusable prompt templates with variables, making it easy to format inputs for your language models. This is crucial because the quality of your prompts directly impacts the quality of your outputs.\n\nThird, Chains are a fundamental concept. A chain is a sequence of calls to components - typically LLMs, but also other tools. Instead of making individual API calls, you can create chains that automate complex workflows. For example, you might create a chain that reads data, processes it, generates an answer, and formats the output.\n\nFourth, Memory is essential for conversational AI. Langchain provides several memory types to maintain conversation history. You can keep track of previous interactions, which is vital for creating chatbots that understand context and can have meaningful, coherent conversations.\n\nFifth, Agents are intelligent systems that can make decisions. Unlike chains with fixed sequences, agents use an LLM to decide which tools to use and in what order. They can reason through problems, use external tools when needed, and adapt their approach based on circumstances. This is like giving your application a brain that can think and decide.\n\nSixth, Data Ingestion and Vectorization. Langchain helps you load data from various sources - PDFs, websites, databases, APIs. It can split documents into manageable chunks and convert them into vector embeddings. This is crucial for building applications that work with large knowledge bases.\n\nFinally, we have Retrievers and Indexes. These components help you find relevant information from your data. When building a question-answering system, for instance, you can retrieve the most relevant chunks from your knowledge base and pass them to the LLM for answering.\n\n## Real-World Applications\n\nSo what can you build with Langchain?\n\nQuestion-Answering Systems: Upload documents, ask questions, and get answers based on your specific data. Unlike just using ChatGPT, your system can be grounded in your own knowledge base.\n\nChatbots: Build conversational agents that understand context, remember previous interactions, and can perform actions by using tools and APIs.\n\nSummarization Tools: Automatically summarize long documents or web pages, maintaining key information while reducing length.\n\nData Analysis Assistants: Create agents that can analyze data, generate insights, and write reports automatically.\n\nContent Generation Pipelines: Build workflows that generate content, from blog posts to code, with multiple steps and quality checks.\n\n## Langchain's Fle ...

# %%
speech = ""
with open("speech.txt") as f:
    speech = f.read()

speech

text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=20)
text = text_splitter.create_documents([speech])
print(text[0])
print(text[1])
# Out:
# page_content='LANGCHAIN: Building Intelligent Applications with'
# page_content='Applications with Language Models'

# %%
type(text[0])
# Out:
# langchain_core.documents.base.Document
