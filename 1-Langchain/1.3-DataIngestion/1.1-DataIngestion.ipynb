# %%
# %pip install langchain langchain_community -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
## Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("speech.txt")
loader

# %%
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content="LANGCHAIN: Building Intelligent Applications with Language Models\n\nHello everyone, and welcome! Today, I want to introduce you to Langchain, a revolutionary framework that is transforming how we build applications with Large Language Models.\n\n## What is Langchain?\n\nLangchain is an open-source framework designed to simplify the development of applications powered by language models. It provides a set of tools, abstractions, and integrations that make it easier to work with LLMs like GPT-4, Llama, and others. Think of it as a bridge between your application and the power of language models.\n\n## The Core Problem\n\nBefore Langchain, building LLM applications was complex. Developers had to manage API calls, handle tokens, maintain conversation history, manage data pipelines, and integrate multiple components. This was time-consuming and error-prone. Langchain solves this by providing ready-to-use components and abstractio
# ...

# %%
# %pip install pypdf -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
## Reading a pdf file
from langchain_community.document_loaders import PyPDFLoader
pdfLoader = PyPDFLoader("sample.pdf")
docs = pdfLoader.load()
docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-06-17T19:59:43+05:30', 'author': 'Rashmi Bharti', 'moddate': '2026-06-17T19:59:43+05:30', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content="LANGCHAIN: Building Intelligent Applications with Language Models \n \nHello everyone, and welcome! Today, I want to introduce you to Langchain, \na revolutionary framework that is transforming how we build applications \nwith Large Language Models. \n \n## What is Langchain? \n \nLangchain is an open-source framework designed to simplify the \ndevelopment of applications powered by language models. It provides a set \nof tools, abstractions, and integrations that make it easier to work with \nLLMs like GPT-4, Llama, and others. Think of it as a bridge between your \napplication and the power of language models. \n \n## The Core Problem \n \nBefore Langchain, building LLM applications was complex. D
# ...

# %%
type(docs)
# Out:
# list

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
# %pip install bs4 -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
## Web Based Loader
import bs4
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_paths=("https://en.wikipedia.org/wiki/Artificial_intelligence",),
                       bs_kwargs=dict(parse_only=bs4.SoupStrainer(
                           class_=("post-title","post-content","post-header")
                       ))
                       )
web = loader.load()    
web
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Artificial_intelligence'}, page_content='')]

# %%
# %pip install arxiv==1.4.7 -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymupdf -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
## Directory Loader - Load multiple text files from a directory
from langchain_community.document_loaders import DirectoryLoader, TextLoader

# Create a simple loader that will load all .txt files from the current directory
directory_loader = DirectoryLoader('.', glob="*.txt", loader_cls=TextLoader)
documents = directory_loader.load()
print(f"Loaded {len(documents)} documents from directory")
print(f"First document preview: {documents[0].page_content[:100]}...")
# Out:
# Loaded 1 documents from directory
# First document preview: LANGCHAIN: Building Intelligent Applications with Language Models
#
# Hello everyone, and welcome! Toda...

# %%
from langchain_community.document_loaders import WikipediaLoader
docs = WikipediaLoader(query = "Generative AI", load_max_docs=2).load()
len(docs)
print(docs)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\rashm\Langchain\venv\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\rashm\Langchain\venv\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
