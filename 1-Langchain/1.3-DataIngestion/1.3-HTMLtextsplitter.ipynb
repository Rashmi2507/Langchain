# %%
# %pip install langchain-text-splitters -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import HTMLSectionSplitter
html_string = """
<html>
    <head>
        <title>Sample HTML</title>
    </head>
    <body>
        <h1>Welcome to My Website</h1>
        <p>This is a sample HTML document. It contains various elements such as headings, paragraphs, and lists.</p>
        <ul>
            <li>Item 1</li>
            <li>Item 2</li>
            <li>Item 3</li>
        </ul>
        <h2>About Me</h2>
        <p>I am a web developer with a passion for creating interactive and user-friendly websites.</p>
        <h3>Contact Information</h3>
        <p>You can reach me at 876545</p>
        <p>Feel free to explore and modify this HTML code as needed.</p>
    </body>
</html>
"""

headers_to_split_on = [("h1", "Header 1"), ("h2", "Header 2"), ("h3", "Header 3")]
html_splitter = HTMLSectionSplitter(headers_to_split_on=headers_to_split_on)
split_docs = html_splitter.split_text(html_string)
split_docs
# Out:
# [Document(metadata={'Header 1': 'Welcome to My Website'}, page_content='Welcome to My Website \n This is a sample HTML document. It contains various elements such as headings, paragraphs, and lists. \n \n Item 1 \n Item 2 \n Item 3'),
#  Document(metadata={'Header 2': 'About Me'}, page_content='About Me \n I am a web developer with a passion for creating interactive and user-friendly websites.'),
#  Document(metadata={'Header 3': 'Contact Information'}, page_content='Contact Information \n You can reach me at 876545 \n Feel free to explore and modify this HTML code as needed.')]
